# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('data/Minjust2018.csv', 
                 header=None, 
                 usecols=[4, 27, 28, 33])
df.fillna('', inplace=True)
df.rename(columns={4: 'name', 
                   27: 'director', 
                   28: 'activity', 
                   33: 'founders'},
              inplace = True)

# %%
df
# Out:
#                                                      name  \
# 0       Коммерческий кооператив "Семеноводческий произ...
# 1                                       ОО "Кайберен эне"
# 2       Общество с ограниченной ответственностью "Дете...
# 3                  Иностранное Казахское ОсОО "Валькирия"
# 4                                          ОсОО "Harour''
# 5       Государственное предприятие "Иссык-кульское ры...
# 6                        ОсОО Редакция газеты " Эл созу "
# 7            РО "Церковь Евангельских христиан-баптистов"
# 8         Общество с ограниченной ответственностью "Вояж"
# 9             РО "Церковь Евангельских Христян-баптистов"
# 10      Общество с ограниченной ответственностью "Мана...
# 11      Совместное кыргызско-казахстанское общество с ...
# 12                 Производственный кооператив "Кожешкен"
# 13               Государственное предприятие "МЭЭНЕТ-УЮТ"
# 14           Южное отделение Национального агенства связи
# ...

# %%
pattern = re.compile(r'(\A|\s)[аоуыиэюеяёй]{2,}($|\s)',
                         re.IGNORECASE)

# %%
df.loc[df['director'].str.contains(pattern)]
# Out:
# C:\Users\Admin\Miniconda3\envs\myenv\lib\site-packages\ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#                                                      name  \
# 349                     Кыргызско-Китайское ОсОО "Залив "
# 1867    ООО  Иностранное  китайское  "КОМПАНИЯ  ЗОЛОТО...
# 2074     Совместное Кыргызско-Китайское предприятие "ФДК"
# 2528    Общественное объединение "Центр гендерных иссл...
# 3713    Общество с ограниченной ответственностью «Кита...
# 5695    Общество с ограниченной ответственностью "DT M...
# 6327    Общество с ограниченной ответственностью "DaDe...
# 7385    Общество с ограниченной ответственностью "ГДК ...
# 9571    Общество с ограниченной ответственностью «ДАФУ...
# 10641   Общество с ограниченной ответственностью "Кен ...
# 11844    Общество с ограниченной ответственностью «Тай К»
# ...
